# %% [markdown]
# # 🧪 Notebook 03 — Kafka Producer
# This notebook:
#
# ✔ Loads schema from transaction-metadata wheel<br>
# ✔ Encodes data to Avro<br>
# ✔ Publishes to Kafka<br>

# %%
import sys

# Ensure transaction-metadata is in the path
transaction_metadata_path = "/Users/manojitroy/flink-practice/transaction-project/transaction-metadata"
if transaction_metadata_path not in sys.path:
    sys.path.insert(0, transaction_metadata_path)

from transaction_metadata.loader import get_schema

# %%
transaction_schema = get_schema("transaction", version="v1")
transaction_schema
# Out:
# {'type': 'record',
#  'name': 'Transaction',
#  'namespace': 'com.company.data',
#  'fields': [{'name': 'transaction_id', 'type': 'string'},
#   {'name': 'user_id', 'type': 'string'},
#   {'name': 'amount', 'type': 'double'},
#   {'name': 'currency', 'type': 'string'},
#   {'name': 'merchant_name', 'type': 'string'},
#   {'name': 'merchant_category', 'type': ['null', 'string'], 'default': None},
#   {'name': 'transaction_type', 'type': 'string'},
#   {'name': 'timestamp', 'type': 'long', 'logicalType': 'timestamp-millis'},
#   {'name': 'device_id', 'type': ['null', 'string'], 'default': None},
#   {'name': 'location', 'type': ['null', 'string'], 'default': None},
#   {'name': 'status', 'type': 'string'}]}

# %%
# %pip install avro-python3
from fastavro import schemaless_writer
from io import BytesIO
import io
import avro.schema
import avro.io

def encode_avro_fastavro(data, schema):
    """Encode data to Avro binary format using fastavro."""
    buf = BytesIO()
    schemaless_writer(buf, schema, data)
    return buf.getvalue()

def encode_avro(data, schema):
    """Encode data to Avro binary format using avro library."""
    bytes_writer = io.BytesIO()
    encoder = avro.io.BinaryEncoder(bytes_writer)
    parsed_schema = avro.schema.parse(str(schema))
    writer = avro.io.DatumWriter(parsed_schema)
    writer.write(data, encoder)
    return bytes_writer.getvalue()
# Out:
# Requirement already satisfied: avro-python3 in /Users/manojitroy/flink-practice/transaction-project/virutual-env/lib/python3.14/site-packages (1.10.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from confluent_kafka import Producer, Consumer, KafkaException

def create_producer(bootstrap_servers="localhost:9092"):
    """Create a Kafka producer."""
    config = {
        "bootstrap.servers": bootstrap_servers,
        "acks": "all",
        "compression.type": "lz4",
    }
    return Producer(config)

def send_message(producer, topic, key, value):
    """Send a message to Kafka."""
    try:
        producer.produce(topic, key=key, value=value)
        producer.flush()
    except KafkaException as e:
        print(f"Kafka send error: {e}")

def create_consumer(topic, group_id="transaction-validator", bootstrap_servers="localhost:9092"):
    """Create a Kafka consumer."""
    config = {
        "bootstrap.servers": bootstrap_servers,
        "group.id": group_id,
        "auto.offset.reset": "earliest"
    }
    consumer = Consumer(config)
    consumer.subscribe([topic])
    return consumer

def consume_messages(consumer, max_messages=10):
    """Fetch up to N messages from Kafka."""
    messages = []
    while len(messages) < max_messages:
        msg = consumer.poll(timeout=1.0)
        if msg is None:
            continue
        if msg.error():
            print("Kafka error:", msg.error())
            continue
        messages.append(msg)
    return messages

# %%
# Utility to build a transaction and send a single message to Kafka
import sys
import pathlib
import json

# Try to import transaction_utils. If it's a local module in the repo (likely in
# transaction-data-simulator), add that path to sys.path and retry.
try:
    from transaction_utils import build_transaction
except ModuleNotFoundError:
    # Determine a reasonable candidate path:
    # Use transaction_metadata_path (already present in the notebook) to find project root,
    # then look for 'transaction-data-simulator' sibling folder.
    project_root = pathlib.Path(transaction_metadata_path).parent if 'transaction_metadata_path' in globals() else pathlib.Path.cwd()
    candidate = str(project_root / 'transaction-data-simulator')
    if candidate not in sys.path:
        sys.path.insert(0, candidate)
    try:
        from transaction_utils import build_transaction
    except ModuleNotFoundError:
        # Helpful error if still not found
        raise ModuleNotFoundError(
            f"transaction_utils not found. Checked candidate path: {candidate}. "
            "If this is a pip package, install it with: %pip install transaction-utils"
        )

def send_single_message(topic, producer=None, bootstrap_servers="localhost:9092"):
    """Build a transaction and send it to `topic` using the available producer util."""
    # Create a producer if none provided
    if producer is None:
        producer = create_producer(bootstrap_servers)

    # Build the event
    event = build_transaction()

    # Encode to Avro binary if schema is available, otherwise JSON bytes
    try:
        if 'transaction_schema' in globals() and transaction_schema is not None:
            print('Encoding event to Avro using fastavro')
            value = encode_avro_fastavro(event, transaction_schema)
        else:
            print('No schema found, falling back to JSON bytes')
            value = json.dumps(event).encode('utf-8')
    except Exception as e:
        print('Encoding to Avro failed, falling back to JSON bytes:', e)
        value = json.dumps(event).encode('utf-8')

    key = event.get('transaction_id')
    if isinstance(key, str):
        key = key.encode('utf-8')

    # Use existing helper to send (handles flush & errors)
    send_message(producer, topic, key, value)

    return event

# %%
p = create_producer()

# %%
from time import sleep


while True:
    sent_event = send_single_message('transactions', producer=p)
    print('Sent:', sent_event)
    sleep(1)
# Out:
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd3b940d9-e79b-4180-b808-a74db37d7bae', 'user_id': '5936a209-b469-475f-9c9e-6228c79261a3', 'amount': 3054.38, 'currency': 'USD', 'merchant_name': 'Myntra - Online Services - F1HV     ', 'merchant_category': ' Food', 'transaction_type': 'purchase', 'timestamp': 1763820006641, 'device_id': '5eab3a83-e2f9-4d81-a9e1-f95ad43fec61', 'location': 'Tokyo - JCE', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'df1b6db8-13cc-42f9-842d-ec03f230f010', 'user_id': '6e1cd218-c5f6-4244-a543-b2a6fe94b378', 'amount': 4523.77, 'currency': 'USD', 'merchant_name': 'Tata - Travel - K4I7                ', 'merchant_category': ' Grocery', 'transaction_type': 'purchase', 'timestamp': 1763820007654, 'device_id': 'e5273787-5d36-49d9-b1af-ba3f11ba958d', 'location': 'Lucknow - QYG', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'df1b6db8-13cc-42f9-842d-ec03f230f010', 'user_id': '6e1cd218-c5f6-4244-a543-b2a6fe94b378', 'amount': 4523.77, 'currency': 'USD', 'merchant_name': 'Tata - Travel - K4I7                ', 'merchant_category': ' Grocery', 'transaction_type': 'purchase', 'timestamp': 1763820007654, 'device_id': 'e5273787-5d36-49d9-b1af-ba3f11ba958d', 'location': 'Lucknow - QYG', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a73e91af-c3ae-4559-ad8b-1f87134c5ebf', 'user_id': '651392df-17df-497c-88d5-08fa78f5b35d', 'amount': 1142.22, 'currency': 'USD', 'merchant_name': 'Amazon - Healthcare - G9EY          ', 'merchant_category': ' Automobile', 'transaction_type': 'purchase', 'timestamp': 1763820008660, 'device_id': '0fb466b0-6682-4b31-863a-b47b7d0fe373', 'location': 'Pune - FKU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a73e91af-c3ae-4559-ad8b-1f87134c5ebf', 'user_id': '651392df-17df-497c-88d5-08fa78f5b35d', 'amount': 1142.22, 'currency': 'USD', 'merchant_name': 'Amazon - Healthcare - G9EY          ', 'merchant_category': ' Automobile', 'transaction_type': 'purchase', 'timestamp': 1763820008660, 'device_id': '0fb466b0-6682-4b31-863a-b47b7d0fe373', 'location': 'Pune - FKU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'f006304b-5614-4c87-9550-cfc05ddf1df8', 'user_id': '12bb924b-6c22-44b3-9971-d238842824cd', 'amount': 3734.14, 'currency': 'USD', 'merchant_name': 'Zomato - Automobile - IV5P          ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820009668, 'device_id': '01fa8863-509f-4838-9144-92f7258f8411', 'location': 'Tokyo - FZI', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'f006304b-5614-4c87-9550-cfc05ddf1df8', 'user_id': '12bb924b-6c22-44b3-9971-d238842824cd', 'amount': 3734.14, 'currency': 'USD', 'merchant_name': 'Zomato - Automobile - IV5P          ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820009668, 'device_id': '01fa8863-509f-4838-9144-92f7258f8411', 'location': 'Tokyo - FZI', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '8441b6fe-af29-4787-8c00-3ce85a6fa385', 'user_id': '145ca41e-d6af-4b8f-8230-fde366988f59', 'amount': 3488.29, 'currency': 'USD', 'merchant_name': 'Amazon - Food - N1NU                ', 'merchant_category': ' Electronics', 'transaction_type': 'refund', 'timestamp': 1763820010670, 'device_id': '50a66f65-9f01-4879-91e8-c08235bc57b8', 'location': 'Hyderabad - IFZ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '8441b6fe-af29-4787-8c00-3ce85a6fa385', 'user_id': '145ca41e-d6af-4b8f-8230-fde366988f59', 'amount': 3488.29, 'currency': 'USD', 'merchant_name': 'Amazon - Food - N1NU                ', 'merchant_category': ' Electronics', 'transaction_type': 'refund', 'timestamp': 1763820010670, 'device_id': '50a66f65-9f01-4879-91e8-c08235bc57b8', 'location': 'Hyderabad - IFZ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '52f9da98-2ac1-404f-9159-55d5ca011157', 'user_id': '98508e1c-ab3f-4cc3-be7b-a485d791f3ac', 'amount': 3930.42, 'currency': 'USD', 'merchant_name': 'Flipkart - Food - M9A9              ', 'merchant_category': ' Grocery', 'transaction_type': 'refund', 'timestamp': 1763820011674, 'device_id': 'c17da5c3-626d-47dd-8d9a-ac238a715432', 'location': 'Mumbai - HGV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '52f9da98-2ac1-404f-9159-55d5ca011157', 'user_id': '98508e1c-ab3f-4cc3-be7b-a485d791f3ac', 'amount': 3930.42, 'currency': 'USD', 'merchant_name': 'Flipkart - Food - M9A9              ', 'merchant_category': ' Grocery', 'transaction_type': 'refund', 'timestamp': 1763820011674, 'device_id': 'c17da5c3-626d-47dd-8d9a-ac238a715432', 'location': 'Mumbai - HGV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '599497f9-bc6c-47a1-a368-1b2425643964', 'user_id': 'f6983c41-f03d-4958-9cf9-9cee8ec87f51', 'amount': 4704.01, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - WPE3     ', 'merchant_category': ' Online Services', 'transaction_type': 'refund', 'timestamp': 1763820012683, 'device_id': '3b9f8d8d-0c09-4544-a88d-569c7aa9ecd0', 'location': 'Ahmedabad - VOJ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '599497f9-bc6c-47a1-a368-1b2425643964', 'user_id': 'f6983c41-f03d-4958-9cf9-9cee8ec87f51', 'amount': 4704.01, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - WPE3     ', 'merchant_category': ' Online Services', 'transaction_type': 'refund', 'timestamp': 1763820012683, 'device_id': '3b9f8d8d-0c09-4544-a88d-569c7aa9ecd0', 'location': 'Ahmedabad - VOJ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2aa42cfa-4c6f-4d65-bcf5-6d3d5cdf89ab', 'user_id': '2c4007a2-8f61-4250-9ab6-924b9de453d5', 'amount': 2739.76, 'currency': 'USD', 'merchant_name': 'Zomato - Online Services - 288N     ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820013688, 'device_id': 'c86560ae-03be-4012-a29c-2789202cef27', 'location': 'Dubai - NII', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2aa42cfa-4c6f-4d65-bcf5-6d3d5cdf89ab', 'user_id': '2c4007a2-8f61-4250-9ab6-924b9de453d5', 'amount': 2739.76, 'currency': 'USD', 'merchant_name': 'Zomato - Online Services - 288N     ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820013688, 'device_id': 'c86560ae-03be-4012-a29c-2789202cef27', 'location': 'Dubai - NII', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bb9b1a89-d1da-41d8-bf6e-890e9eef85b5', 'user_id': '9aced308-8e4e-4c3b-9af1-700cefbd3a7d', 'amount': 1207.5, 'currency': 'USD', 'merchant_name': 'Uber - Automobile - GA6B            ', 'merchant_category': ' Food', 'transaction_type': 'withdrawal', 'timestamp': 1763820014692, 'device_id': '1c486739-9075-44b9-ab3f-16c2554ae7be', 'location': 'London - CWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bb9b1a89-d1da-41d8-bf6e-890e9eef85b5', 'user_id': '9aced308-8e4e-4c3b-9af1-700cefbd3a7d', 'amount': 1207.5, 'currency': 'USD', 'merchant_name': 'Uber - Automobile - GA6B            ', 'merchant_category': ' Food', 'transaction_type': 'withdrawal', 'timestamp': 1763820014692, 'device_id': '1c486739-9075-44b9-ab3f-16c2554ae7be', 'location': 'London - CWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'b7148e83-a5c7-46d9-879f-06c87e138484', 'user_id': '77c00c89-51ef-451c-8329-91e33edb058d', 'amount': 2553.09, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - 66FX          ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820015697, 'device_id': '0d78a2a8-2947-4085-932d-caa7e286fbe2', 'location': 'Tokyo - PUO', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'b7148e83-a5c7-46d9-879f-06c87e138484', 'user_id': '77c00c89-51ef-451c-8329-91e33edb058d', 'amount': 2553.09, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - 66FX          ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820015697, 'device_id': '0d78a2a8-2947-4085-932d-caa7e286fbe2', 'location': 'Tokyo - PUO', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'f2bee055-4a64-4559-8ecd-aeba76012bde', 'user_id': 'c7ae729c-b57b-4991-a4c2-17043bc48b6a', 'amount': 1204.51, 'currency': 'USD', 'merchant_name': 'Myntra - Travel - 19EV              ', 'merchant_category': ' Travel', 'transaction_type': 'purchase', 'timestamp': 1763820016701, 'device_id': '2723d492-1e99-4b84-959c-1b40a122834e', 'location': 'Hyderabad - CWI', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'f2bee055-4a64-4559-8ecd-aeba76012bde', 'user_id': 'c7ae729c-b57b-4991-a4c2-17043bc48b6a', 'amount': 1204.51, 'currency': 'USD', 'merchant_name': 'Myntra - Travel - 19EV              ', 'merchant_category': ' Travel', 'transaction_type': 'purchase', 'timestamp': 1763820016701, 'device_id': '2723d492-1e99-4b84-959c-1b40a122834e', 'location': 'Hyderabad - CWI', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '96077a42-bdf2-49c4-a388-7c299e7d3d71', 'user_id': '4139b95e-08b5-405b-bde7-6d6d6e5b0f11', 'amount': 3168.34, 'currency': 'USD', 'merchant_name': 'Myntra - Grocery - DAP4             ', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820017704, 'device_id': '411caed0-8472-44f1-a5f1-730c193391ea', 'location': 'Jaipur - IJX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '96077a42-bdf2-49c4-a388-7c299e7d3d71', 'user_id': '4139b95e-08b5-405b-bde7-6d6d6e5b0f11', 'amount': 3168.34, 'currency': 'USD', 'merchant_name': 'Myntra - Grocery - DAP4             ', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820017704, 'device_id': '411caed0-8472-44f1-a5f1-730c193391ea', 'location': 'Jaipur - IJX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a0439bff-be96-43b7-8098-e2aa8e01ca72', 'user_id': '8d9dcce9-3ab7-44bb-8a0b-741eaf4422b8', 'amount': 132.38, 'currency': 'USD', 'merchant_name': 'Swiggy - Online Services - BRL0     ', 'merchant_category': ' Fashion', 'transaction_type': 'purchase', 'timestamp': 1763820018709, 'device_id': 'dfc31ebc-1864-45fe-8fcb-fa2f38de61c7', 'location': 'Pune - ERW', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a0439bff-be96-43b7-8098-e2aa8e01ca72', 'user_id': '8d9dcce9-3ab7-44bb-8a0b-741eaf4422b8', 'amount': 132.38, 'currency': 'USD', 'merchant_name': 'Swiggy - Online Services - BRL0     ', 'merchant_category': ' Fashion', 'transaction_type': 'purchase', 'timestamp': 1763820018709, 'device_id': 'dfc31ebc-1864-45fe-8fcb-fa2f38de61c7', 'location': 'Pune - ERW', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '593d7118-804c-4b62-bfff-3ccddb5bc757', 'user_id': 'd5f75e3f-4660-4b27-be3c-8b88a8923a25', 'amount': 2909.21, 'currency': 'USD', 'merchant_name': 'Amazon - Travel - CTJG              ', 'merchant_category': ' Healthcare', 'transaction_type': 'withdrawal', 'timestamp': 1763820019718, 'device_id': 'd5921eda-4207-4077-85bd-2eb17e49ef32', 'location': 'Hyderabad - MRL', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '593d7118-804c-4b62-bfff-3ccddb5bc757', 'user_id': 'd5f75e3f-4660-4b27-be3c-8b88a8923a25', 'amount': 2909.21, 'currency': 'USD', 'merchant_name': 'Amazon - Travel - CTJG              ', 'merchant_category': ' Healthcare', 'transaction_type': 'withdrawal', 'timestamp': 1763820019718, 'device_id': 'd5921eda-4207-4077-85bd-2eb17e49ef32', 'location': 'Hyderabad - MRL', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '122959f0-f9f7-4719-9c36-36c44fcb3e7b', 'user_id': '7ac283c9-4116-4f21-8722-0c2108427eb8', 'amount': 3583.36, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Healthcare - 046Q     ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820020725, 'device_id': '4c45302f-691e-4873-9274-e0afadd16889', 'location': 'Ahmedabad - ZVR', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '122959f0-f9f7-4719-9c36-36c44fcb3e7b', 'user_id': '7ac283c9-4116-4f21-8722-0c2108427eb8', 'amount': 3583.36, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Healthcare - 046Q     ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820020725, 'device_id': '4c45302f-691e-4873-9274-e0afadd16889', 'location': 'Ahmedabad - ZVR', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7a557434-f12e-4c73-ad1f-9b02ced8e8a4', 'user_id': '46c9bc7c-61ff-4516-b92c-e717ed527aa6', 'amount': 2969.29, 'currency': 'USD', 'merchant_name': 'Reliance - Food - YN9T              ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820021729, 'device_id': '74be47ca-4089-4760-8d73-e461497976f5', 'location': 'Tokyo - ZSV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7a557434-f12e-4c73-ad1f-9b02ced8e8a4', 'user_id': '46c9bc7c-61ff-4516-b92c-e717ed527aa6', 'amount': 2969.29, 'currency': 'USD', 'merchant_name': 'Reliance - Food - YN9T              ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820021729, 'device_id': '74be47ca-4089-4760-8d73-e461497976f5', 'location': 'Tokyo - ZSV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '92d04e36-81f1-465b-98f5-d4406df45014', 'user_id': 'c3407503-811a-430a-9b69-b99ee4fa00c6', 'amount': 2726.13, 'currency': 'USD', 'merchant_name': 'Uber - Travel - DYPX                ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820022737, 'device_id': 'e96ac3c8-1e8a-46ab-b06c-a772d2d44445', 'location': 'Paris - OAW', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '92d04e36-81f1-465b-98f5-d4406df45014', 'user_id': 'c3407503-811a-430a-9b69-b99ee4fa00c6', 'amount': 2726.13, 'currency': 'USD', 'merchant_name': 'Uber - Travel - DYPX                ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820022737, 'device_id': 'e96ac3c8-1e8a-46ab-b06c-a772d2d44445', 'location': 'Paris - OAW', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'ba0005fd-1d3a-4d62-8855-f7407eca0d16', 'user_id': '1f1c337e-5a80-448b-84e8-50d268698318', 'amount': 1966.67, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - AURW          ', 'merchant_category': ' Food', 'transaction_type': 'transfer', 'timestamp': 1763820023742, 'device_id': '4090645c-20bc-40de-a2dc-b23a9a4b2e11', 'location': 'Ahmedabad - BDU', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'ba0005fd-1d3a-4d62-8855-f7407eca0d16', 'user_id': '1f1c337e-5a80-448b-84e8-50d268698318', 'amount': 1966.67, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - AURW          ', 'merchant_category': ' Food', 'transaction_type': 'transfer', 'timestamp': 1763820023742, 'device_id': '4090645c-20bc-40de-a2dc-b23a9a4b2e11', 'location': 'Ahmedabad - BDU', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bcd0a2cf-1773-4456-a632-88f80744688e', 'user_id': '6d556bd9-dd88-466b-a331-efa6643f2833', 'amount': 4943.83, 'currency': 'USD', 'merchant_name': 'Zomato - Electronics - D26P         ', 'merchant_category': ' Online Services', 'transaction_type': 'purchase', 'timestamp': 1763820024748, 'device_id': '1f1c2f66-2e12-4dff-9aba-165df2bea157', 'location': 'Jaipur - NLV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bcd0a2cf-1773-4456-a632-88f80744688e', 'user_id': '6d556bd9-dd88-466b-a331-efa6643f2833', 'amount': 4943.83, 'currency': 'USD', 'merchant_name': 'Zomato - Electronics - D26P         ', 'merchant_category': ' Online Services', 'transaction_type': 'purchase', 'timestamp': 1763820024748, 'device_id': '1f1c2f66-2e12-4dff-9aba-165df2bea157', 'location': 'Jaipur - NLV', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a3bcd919-f1f2-4f04-94d9-167672701199', 'user_id': 'd1d065cd-c7d6-4347-92eb-054e575992ea', 'amount': 1840.12, 'currency': 'USD', 'merchant_name': 'Swiggy - Online Services - TZ6H     ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820025756, 'device_id': 'a792d5a4-0c41-4b68-a3a2-2b06f8ef4993', 'location': 'Singapore - GMS', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a3bcd919-f1f2-4f04-94d9-167672701199', 'user_id': 'd1d065cd-c7d6-4347-92eb-054e575992ea', 'amount': 1840.12, 'currency': 'USD', 'merchant_name': 'Swiggy - Online Services - TZ6H     ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820025756, 'device_id': 'a792d5a4-0c41-4b68-a3a2-2b06f8ef4993', 'location': 'Singapore - GMS', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '63eee14d-48e2-4a54-a748-1106751101e5', 'user_id': '1498e464-69a2-47fd-8c1e-38c73a767c0a', 'amount': 3588.6, 'currency': 'USD', 'merchant_name': 'Swiggy - Food - EH0U                ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820026763, 'device_id': 'ef72610c-5cc1-4b93-8432-d7834ee284bf', 'location': 'Toronto - ZEE', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '63eee14d-48e2-4a54-a748-1106751101e5', 'user_id': '1498e464-69a2-47fd-8c1e-38c73a767c0a', 'amount': 3588.6, 'currency': 'USD', 'merchant_name': 'Swiggy - Food - EH0U                ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820026763, 'device_id': 'ef72610c-5cc1-4b93-8432-d7834ee284bf', 'location': 'Toronto - ZEE', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '32d2cf74-cb9b-46e1-bad5-324a70d2268e', 'user_id': '17f132a7-6b29-4606-a511-c54f4201b2a9', 'amount': 3107.28, 'currency': 'USD', 'merchant_name': 'Amazon - Fashion - 2BVA             ', 'merchant_category': ' Online Services', 'transaction_type': 'purchase', 'timestamp': 1763820027765, 'device_id': '08b8ee87-5356-494f-a619-27c1b535de5d', 'location': 'Kolkata - FCX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '32d2cf74-cb9b-46e1-bad5-324a70d2268e', 'user_id': '17f132a7-6b29-4606-a511-c54f4201b2a9', 'amount': 3107.28, 'currency': 'USD', 'merchant_name': 'Amazon - Fashion - 2BVA             ', 'merchant_category': ' Online Services', 'transaction_type': 'purchase', 'timestamp': 1763820027765, 'device_id': '08b8ee87-5356-494f-a619-27c1b535de5d', 'location': 'Kolkata - FCX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '664f3f4f-b9a4-4718-9e86-ac21ac9a6320', 'user_id': '26372e85-6c84-48c8-828c-8f30204d4c7a', 'amount': 194.4, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - ZQDM     ', 'merchant_category': ' Grocery', 'transaction_type': 'purchase', 'timestamp': 1763820028770, 'device_id': 'c9569a43-4089-486d-bf88-47810e55a284', 'location': 'Hyderabad - GXG', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '664f3f4f-b9a4-4718-9e86-ac21ac9a6320', 'user_id': '26372e85-6c84-48c8-828c-8f30204d4c7a', 'amount': 194.4, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - ZQDM     ', 'merchant_category': ' Grocery', 'transaction_type': 'purchase', 'timestamp': 1763820028770, 'device_id': 'c9569a43-4089-486d-bf88-47810e55a284', 'location': 'Hyderabad - GXG', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3f132c7c-4e9a-46f3-9e8c-c6b45f438656', 'user_id': '1354dbe7-76c0-49bf-a48b-ea7a0f83eae2', 'amount': 4830.64, 'currency': 'USD', 'merchant_name': 'Amazon - Grocery - 1247             ', 'merchant_category': ' Healthcare', 'transaction_type': 'purchase', 'timestamp': 1763820029795, 'device_id': 'bb9be048-8a1c-40a8-b2e6-fa376318dec8', 'location': 'Dubai - GKX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3f132c7c-4e9a-46f3-9e8c-c6b45f438656', 'user_id': '1354dbe7-76c0-49bf-a48b-ea7a0f83eae2', 'amount': 4830.64, 'currency': 'USD', 'merchant_name': 'Amazon - Grocery - 1247             ', 'merchant_category': ' Healthcare', 'transaction_type': 'purchase', 'timestamp': 1763820029795, 'device_id': 'bb9be048-8a1c-40a8-b2e6-fa376318dec8', 'location': 'Dubai - GKX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '01620a00-572c-4336-9cb2-3f8361f1eda5', 'user_id': '401bcfb4-4226-4cfe-a3ae-a48b8352fa70', 'amount': 2446.31, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - 838R          ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820030799, 'device_id': '673ff776-f425-4a2a-9d88-66cd3bbbfe17', 'location': 'Delhi - QBJ', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '01620a00-572c-4336-9cb2-3f8361f1eda5', 'user_id': '401bcfb4-4226-4cfe-a3ae-a48b8352fa70', 'amount': 2446.31, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - 838R          ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820030799, 'device_id': '673ff776-f425-4a2a-9d88-66cd3bbbfe17', 'location': 'Delhi - QBJ', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7c766bc2-ae22-4c57-833d-ffc67d07d23b', 'user_id': '9464a517-3721-45c1-be41-c7b332673a25', 'amount': 2044.02, 'currency': 'USD', 'merchant_name': 'Tata - Electronics - 5BYJ           ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820031807, 'device_id': '7bf020d3-71e1-4a39-beba-79daa670838b', 'location': 'Lucknow - LCJ', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7c766bc2-ae22-4c57-833d-ffc67d07d23b', 'user_id': '9464a517-3721-45c1-be41-c7b332673a25', 'amount': 2044.02, 'currency': 'USD', 'merchant_name': 'Tata - Electronics - 5BYJ           ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820031807, 'device_id': '7bf020d3-71e1-4a39-beba-79daa670838b', 'location': 'Lucknow - LCJ', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '71e732c9-c4e7-4fcb-96bb-6cda2eff5931', 'user_id': '3b209a4c-cf03-48eb-adbf-a45b11867754', 'amount': 4327.15, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Travel - XX6A         ', 'merchant_category': ' Online Services', 'transaction_type': 'transfer', 'timestamp': 1763820032814, 'device_id': 'a7a605c7-bf2e-49b9-842e-b2d594471706', 'location': 'Tokyo - ZJV', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '71e732c9-c4e7-4fcb-96bb-6cda2eff5931', 'user_id': '3b209a4c-cf03-48eb-adbf-a45b11867754', 'amount': 4327.15, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Travel - XX6A         ', 'merchant_category': ' Online Services', 'transaction_type': 'transfer', 'timestamp': 1763820032814, 'device_id': 'a7a605c7-bf2e-49b9-842e-b2d594471706', 'location': 'Tokyo - ZJV', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'b546401e-132e-4e2d-a9d6-0a5b6dd9a457', 'user_id': '601a0792-b4c6-4b36-b97c-c98283e81721', 'amount': 4624.66, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - WPE3     ', 'merchant_category': ' Online Services', 'transaction_type': 'transfer', 'timestamp': 1763820033821, 'device_id': '8bdb622e-b99b-47ea-9821-eb991ada3020', 'location': 'Jaipur - QHA', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'b546401e-132e-4e2d-a9d6-0a5b6dd9a457', 'user_id': '601a0792-b4c6-4b36-b97c-c98283e81721', 'amount': 4624.66, 'currency': 'USD', 'merchant_name': 'Amazon - Online Services - WPE3     ', 'merchant_category': ' Online Services', 'transaction_type': 'transfer', 'timestamp': 1763820033821, 'device_id': '8bdb622e-b99b-47ea-9821-eb991ada3020', 'location': 'Jaipur - QHA', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7ea5488f-325e-4ccc-b6b0-73b307b33232', 'user_id': '33f87552-29b0-45f0-b02a-152c3c5a78d1', 'amount': 1862.48, 'currency': 'USD', 'merchant_name': 'Uber - Automobile - VGF2            ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820034831, 'device_id': '66b72cf4-19fc-4167-9527-aa9faf9a69e8', 'location': 'Ahmedabad - LWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7ea5488f-325e-4ccc-b6b0-73b307b33232', 'user_id': '33f87552-29b0-45f0-b02a-152c3c5a78d1', 'amount': 1862.48, 'currency': 'USD', 'merchant_name': 'Uber - Automobile - VGF2            ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820034831, 'device_id': '66b72cf4-19fc-4167-9527-aa9faf9a69e8', 'location': 'Ahmedabad - LWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '036cb514-1899-4143-bf7f-73a8467e06aa', 'user_id': '65b3318d-d366-412c-8a39-e4f033741c49', 'amount': 1724.76, 'currency': 'USD', 'merchant_name': 'Swiggy - Grocery - VLXW             ', 'merchant_category': ' Fashion', 'transaction_type': 'transfer', 'timestamp': 1763820035839, 'device_id': 'ab56b330-4ff8-4278-9896-4f4dfa98e202', 'location': 'Berlin - IYH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '036cb514-1899-4143-bf7f-73a8467e06aa', 'user_id': '65b3318d-d366-412c-8a39-e4f033741c49', 'amount': 1724.76, 'currency': 'USD', 'merchant_name': 'Swiggy - Grocery - VLXW             ', 'merchant_category': ' Fashion', 'transaction_type': 'transfer', 'timestamp': 1763820035839, 'device_id': 'ab56b330-4ff8-4278-9896-4f4dfa98e202', 'location': 'Berlin - IYH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bf5fafca-bc91-4927-82f3-1f0b16495ec8', 'user_id': '0464dcd7-ed9b-474b-8cea-f2c8b524254b', 'amount': 3958.49, 'currency': 'USD', 'merchant_name': 'Tata - Healthcare - J1ZB            ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820036846, 'device_id': 'c09ac5a1-1adc-40d6-b411-dbd24e219db8', 'location': 'Jaipur - QRH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bf5fafca-bc91-4927-82f3-1f0b16495ec8', 'user_id': '0464dcd7-ed9b-474b-8cea-f2c8b524254b', 'amount': 3958.49, 'currency': 'USD', 'merchant_name': 'Tata - Healthcare - J1ZB            ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820036846, 'device_id': 'c09ac5a1-1adc-40d6-b411-dbd24e219db8', 'location': 'Jaipur - QRH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3baf7de1-d363-44f9-822d-8629711edb4f', 'user_id': 'c0d207e3-2fd1-4b81-aaf6-3df37f692fb6', 'amount': 2585.65, 'currency': 'USD', 'merchant_name': 'Swiggy - Fashion - NYDK             ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820037848, 'device_id': '4e23a1a6-38cd-4c42-a08e-a2d542a4221f', 'location': 'Ahmedabad - BFM', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3baf7de1-d363-44f9-822d-8629711edb4f', 'user_id': 'c0d207e3-2fd1-4b81-aaf6-3df37f692fb6', 'amount': 2585.65, 'currency': 'USD', 'merchant_name': 'Swiggy - Fashion - NYDK             ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820037848, 'device_id': '4e23a1a6-38cd-4c42-a08e-a2d542a4221f', 'location': 'Ahmedabad - BFM', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd99417da-7f1b-4a21-852c-d28447a8555b', 'user_id': '31e0a0dd-fa3a-49bb-80ce-dbecc00ef4cd', 'amount': 1099.32, 'currency': 'USD', 'merchant_name': 'Amazon - Automobile - KERN          ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820038855, 'device_id': 'b07fad30-bbd7-48e4-8847-d3d1b0ed3c5c', 'location': 'Dubai - TPU', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd99417da-7f1b-4a21-852c-d28447a8555b', 'user_id': '31e0a0dd-fa3a-49bb-80ce-dbecc00ef4cd', 'amount': 1099.32, 'currency': 'USD', 'merchant_name': 'Amazon - Automobile - KERN          ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820038855, 'device_id': 'b07fad30-bbd7-48e4-8847-d3d1b0ed3c5c', 'location': 'Dubai - TPU', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '04b23f11-8536-4086-8455-1e0003e3ce8f', 'user_id': '66a75b5e-e292-448d-a5b2-f38c67df1d31', 'amount': 669.72, 'currency': 'USD', 'merchant_name': 'Uber - Food - 53QO                  ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820039863, 'device_id': 'e0d5ecc4-cd15-4573-a344-83cabc4249fe', 'location': 'Bengaluru - GRH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '04b23f11-8536-4086-8455-1e0003e3ce8f', 'user_id': '66a75b5e-e292-448d-a5b2-f38c67df1d31', 'amount': 669.72, 'currency': 'USD', 'merchant_name': 'Uber - Food - 53QO                  ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820039863, 'device_id': 'e0d5ecc4-cd15-4573-a344-83cabc4249fe', 'location': 'Bengaluru - GRH', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '5f9c50a5-5099-4c47-9095-6fd5c7e1fa42', 'user_id': '102c2461-85d6-4186-954e-3fb4782f19bf', 'amount': 3225.89, 'currency': 'USD', 'merchant_name': 'Swiggy - Grocery - MFQN             ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820040871, 'device_id': 'a2648105-93b4-4811-8989-fdd426a8ec3c', 'location': 'Singapore - FUU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '5f9c50a5-5099-4c47-9095-6fd5c7e1fa42', 'user_id': '102c2461-85d6-4186-954e-3fb4782f19bf', 'amount': 3225.89, 'currency': 'USD', 'merchant_name': 'Swiggy - Grocery - MFQN             ', 'merchant_category': ' Automobile', 'transaction_type': 'transfer', 'timestamp': 1763820040871, 'device_id': 'a2648105-93b4-4811-8989-fdd426a8ec3c', 'location': 'Singapore - FUU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a05e3157-2a7b-49a2-a630-a5c83f4a825c', 'user_id': '6d99e183-6918-4c02-830f-fdae077dd2c9', 'amount': 955.63, 'currency': 'USD', 'merchant_name': 'Flipkart - Electronics - IQCV       ', 'merchant_category': ' Fashion', 'transaction_type': 'transfer', 'timestamp': 1763820041873, 'device_id': 'ea3c7f60-8908-42b4-b05f-3bbd4eebba1f', 'location': 'Sydney - IKL', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a05e3157-2a7b-49a2-a630-a5c83f4a825c', 'user_id': '6d99e183-6918-4c02-830f-fdae077dd2c9', 'amount': 955.63, 'currency': 'USD', 'merchant_name': 'Flipkart - Electronics - IQCV       ', 'merchant_category': ' Fashion', 'transaction_type': 'transfer', 'timestamp': 1763820041873, 'device_id': 'ea3c7f60-8908-42b4-b05f-3bbd4eebba1f', 'location': 'Sydney - IKL', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd3b95dac-d12e-427c-8cff-694cf0ddf95a', 'user_id': '85a20d58-8c6a-4e09-9234-4d2a7fa24061', 'amount': 3086.2, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Automobile - 8C47     ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820042883, 'device_id': '9017b79e-bac1-419a-a1f8-a6368c698fd6', 'location': 'Ahmedabad - NNJ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd3b95dac-d12e-427c-8cff-694cf0ddf95a', 'user_id': '85a20d58-8c6a-4e09-9234-4d2a7fa24061', 'amount': 3086.2, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Automobile - 8C47     ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820042883, 'device_id': '9017b79e-bac1-419a-a1f8-a6368c698fd6', 'location': 'Ahmedabad - NNJ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '4a657b45-d3ce-4476-a1cc-294a89614528', 'user_id': 'b4fc26fb-0e0c-481b-a8f1-bbd0aed6a13f', 'amount': 4518.51, 'currency': 'USD', 'merchant_name': 'Tata - Electronics - P4TK           ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820043896, 'device_id': '4ba177be-7739-49ba-b3ee-14ded8473915', 'location': 'Tokyo - DLI', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '4a657b45-d3ce-4476-a1cc-294a89614528', 'user_id': 'b4fc26fb-0e0c-481b-a8f1-bbd0aed6a13f', 'amount': 4518.51, 'currency': 'USD', 'merchant_name': 'Tata - Electronics - P4TK           ', 'merchant_category': ' Travel', 'transaction_type': 'withdrawal', 'timestamp': 1763820043896, 'device_id': '4ba177be-7739-49ba-b3ee-14ded8473915', 'location': 'Tokyo - DLI', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2b4f8312-487a-4170-b17e-31753109353a', 'user_id': '90f434a2-1712-4277-ac4d-a51e2abae5b2', 'amount': 3597.67, 'currency': 'USD', 'merchant_name': 'BigBasket - Online Services - JJZS  ', 'merchant_category': ' Automobile', 'transaction_type': 'purchase', 'timestamp': 1763820044898, 'device_id': 'd086952d-4321-4f1a-8983-4b8a0a2bc668', 'location': 'Sydney - MTX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2b4f8312-487a-4170-b17e-31753109353a', 'user_id': '90f434a2-1712-4277-ac4d-a51e2abae5b2', 'amount': 3597.67, 'currency': 'USD', 'merchant_name': 'BigBasket - Online Services - JJZS  ', 'merchant_category': ' Automobile', 'transaction_type': 'purchase', 'timestamp': 1763820044898, 'device_id': 'd086952d-4321-4f1a-8983-4b8a0a2bc668', 'location': 'Sydney - MTX', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '1b99c3ee-c87e-49b1-a2a9-d12febd4a10f', 'user_id': '3e4b1d31-b665-497f-aa7e-4a4643271190', 'amount': 2340.77, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - XEQY      ', 'merchant_category': ' Travel', 'transaction_type': 'refund', 'timestamp': 1763820045905, 'device_id': 'fd558fda-26b5-4d24-8c39-d2c23bebf59a', 'location': 'Pune - CUF', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '1b99c3ee-c87e-49b1-a2a9-d12febd4a10f', 'user_id': '3e4b1d31-b665-497f-aa7e-4a4643271190', 'amount': 2340.77, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - XEQY      ', 'merchant_category': ' Travel', 'transaction_type': 'refund', 'timestamp': 1763820045905, 'device_id': 'fd558fda-26b5-4d24-8c39-d2c23bebf59a', 'location': 'Pune - CUF', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd3d6c508-2321-4fee-90fd-cb4ab4931ddc', 'user_id': 'ed4ad3f0-f220-4c18-855a-8dd3745abad7', 'amount': 208.72, 'currency': 'USD', 'merchant_name': 'Uber - Healthcare - OX4B            ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820046911, 'device_id': '32521cd7-1b32-4a71-8cec-08c4ac974a82', 'location': 'Lucknow - EVT', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd3d6c508-2321-4fee-90fd-cb4ab4931ddc', 'user_id': 'ed4ad3f0-f220-4c18-855a-8dd3745abad7', 'amount': 208.72, 'currency': 'USD', 'merchant_name': 'Uber - Healthcare - OX4B            ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820046911, 'device_id': '32521cd7-1b32-4a71-8cec-08c4ac974a82', 'location': 'Lucknow - EVT', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '8ac1293d-2fe5-42f0-804c-5842187af5ce', 'user_id': 'f8e1cf5c-1bb4-4ae5-993e-53ed9912a819', 'amount': 3568.03, 'currency': 'USD', 'merchant_name': 'Reliance - Electronics - 18OM       ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820047918, 'device_id': 'f6ee4786-9c18-469b-a63c-1f0a7d4b7b0a', 'location': 'Toronto - RSZ', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '8ac1293d-2fe5-42f0-804c-5842187af5ce', 'user_id': 'f8e1cf5c-1bb4-4ae5-993e-53ed9912a819', 'amount': 3568.03, 'currency': 'USD', 'merchant_name': 'Reliance - Electronics - 18OM       ', 'merchant_category': ' Electronics', 'transaction_type': 'withdrawal', 'timestamp': 1763820047918, 'device_id': 'f6ee4786-9c18-469b-a63c-1f0a7d4b7b0a', 'location': 'Toronto - RSZ', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '335c9003-325e-4e2f-bf93-81865e36f9b0', 'user_id': '373e146d-6491-49b4-a65f-ecbfa6cb6fcd', 'amount': 3931.42, 'currency': 'USD', 'merchant_name': 'Swiggy - Healthcare - LN6W          ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820048926, 'device_id': 'ebb1d7cc-d5c8-4978-809d-62a8e5c2f19d', 'location': 'Paris - CWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '335c9003-325e-4e2f-bf93-81865e36f9b0', 'user_id': '373e146d-6491-49b4-a65f-ecbfa6cb6fcd', 'amount': 3931.42, 'currency': 'USD', 'merchant_name': 'Swiggy - Healthcare - LN6W          ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820048926, 'device_id': 'ebb1d7cc-d5c8-4978-809d-62a8e5c2f19d', 'location': 'Paris - CWD', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a3e3eea7-0b4e-404f-8a3c-6c0e4169fb22', 'user_id': '132cf8cc-d536-4f66-9899-49988da624a6', 'amount': 3755.86, 'currency': 'USD', 'merchant_name': 'Reliance - Grocery - CTRA           ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820049934, 'device_id': '44654b4d-5730-4801-9dfd-6303a4c020f4', 'location': 'Mumbai - RVW', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'a3e3eea7-0b4e-404f-8a3c-6c0e4169fb22', 'user_id': '132cf8cc-d536-4f66-9899-49988da624a6', 'amount': 3755.86, 'currency': 'USD', 'merchant_name': 'Reliance - Grocery - CTRA           ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820049934, 'device_id': '44654b4d-5730-4801-9dfd-6303a4c020f4', 'location': 'Mumbai - RVW', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd04703c6-4312-4567-a322-dd7460fe3d51', 'user_id': '4a06ea8c-5332-4686-b51b-58c0b0b14f3d', 'amount': 3884.39, 'currency': 'USD', 'merchant_name': 'BigBasket - Healthcare - F17S       ', 'merchant_category': ' Food', 'transaction_type': 'purchase', 'timestamp': 1763820050942, 'device_id': 'db7d54d9-4576-4628-a237-4c9e80080f49', 'location': 'Singapore - XEI', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd04703c6-4312-4567-a322-dd7460fe3d51', 'user_id': '4a06ea8c-5332-4686-b51b-58c0b0b14f3d', 'amount': 3884.39, 'currency': 'USD', 'merchant_name': 'BigBasket - Healthcare - F17S       ', 'merchant_category': ' Food', 'transaction_type': 'purchase', 'timestamp': 1763820050942, 'device_id': 'db7d54d9-4576-4628-a237-4c9e80080f49', 'location': 'Singapore - XEI', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2208ec50-e6a9-42b7-a8ab-0b06a6d07ff8', 'user_id': 'b62863a7-d7f8-4f94-9cca-cb99ed3cd943', 'amount': 847.85, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - PWWZ      ', 'merchant_category': ' Fashion', 'transaction_type': 'withdrawal', 'timestamp': 1763820051949, 'device_id': '9485ba81-a531-4587-b220-9270e81abf1d', 'location': 'Kolkata - HHB', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2208ec50-e6a9-42b7-a8ab-0b06a6d07ff8', 'user_id': 'b62863a7-d7f8-4f94-9cca-cb99ed3cd943', 'amount': 847.85, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - PWWZ      ', 'merchant_category': ' Fashion', 'transaction_type': 'withdrawal', 'timestamp': 1763820051949, 'device_id': '9485ba81-a531-4587-b220-9270e81abf1d', 'location': 'Kolkata - HHB', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '091c355e-770c-4779-9de1-2fda19d45802', 'user_id': 'd595c3c5-82c4-4407-8af6-d3bb2255b67b', 'amount': 4553.46, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - 208A      ', 'merchant_category': ' Grocery', 'transaction_type': 'withdrawal', 'timestamp': 1763820052955, 'device_id': '6f127212-c474-47c7-8254-558b88db09d5', 'location': 'Berlin - ANI', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '091c355e-770c-4779-9de1-2fda19d45802', 'user_id': 'd595c3c5-82c4-4407-8af6-d3bb2255b67b', 'amount': 4553.46, 'currency': 'USD', 'merchant_name': 'BigBasket - Electronics - 208A      ', 'merchant_category': ' Grocery', 'transaction_type': 'withdrawal', 'timestamp': 1763820052955, 'device_id': '6f127212-c474-47c7-8254-558b88db09d5', 'location': 'Berlin - ANI', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'fcda4384-945b-4bdb-827e-cc1b0be379fd', 'user_id': 'b75d6858-b38e-4747-8094-a4b6e31cb143', 'amount': 1400.61, 'currency': 'USD', 'merchant_name': 'Uber - Healthcare - 2VX1            ', 'merchant_category': ' Grocery', 'transaction_type': 'withdrawal', 'timestamp': 1763820053963, 'device_id': '52246c18-a5d7-457e-b322-89664159276a', 'location': 'Toronto - RSZ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'fcda4384-945b-4bdb-827e-cc1b0be379fd', 'user_id': 'b75d6858-b38e-4747-8094-a4b6e31cb143', 'amount': 1400.61, 'currency': 'USD', 'merchant_name': 'Uber - Healthcare - 2VX1            ', 'merchant_category': ' Grocery', 'transaction_type': 'withdrawal', 'timestamp': 1763820053963, 'device_id': '52246c18-a5d7-457e-b322-89664159276a', 'location': 'Toronto - RSZ', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd02b7ecb-36c5-411d-a9db-c17af40bc91b', 'user_id': '5c48cb69-fd57-449e-800d-c19afc248f29', 'amount': 4389.59, 'currency': 'USD', 'merchant_name': 'Myntra - Travel - MGST              ', 'merchant_category': ' Healthcare', 'transaction_type': 'withdrawal', 'timestamp': 1763820054970, 'device_id': 'bf0b58e0-10a4-4e63-a82a-cd7b98bbba1f', 'location': 'Toronto - ESG', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'd02b7ecb-36c5-411d-a9db-c17af40bc91b', 'user_id': '5c48cb69-fd57-449e-800d-c19afc248f29', 'amount': 4389.59, 'currency': 'USD', 'merchant_name': 'Myntra - Travel - MGST              ', 'merchant_category': ' Healthcare', 'transaction_type': 'withdrawal', 'timestamp': 1763820054970, 'device_id': 'bf0b58e0-10a4-4e63-a82a-cd7b98bbba1f', 'location': 'Toronto - ESG', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '793eca29-e20e-4a27-8e52-2d1682fe3743', 'user_id': '25bc1e80-c508-48ec-97d9-9c8c9e113ebe', 'amount': 1204.76, 'currency': 'USD', 'merchant_name': 'Flipkart - Automobile - 6199        ', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820055976, 'device_id': '3effc2e9-49d7-4a91-902d-9de532191244', 'location': 'Delhi - IVN', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '793eca29-e20e-4a27-8e52-2d1682fe3743', 'user_id': '25bc1e80-c508-48ec-97d9-9c8c9e113ebe', 'amount': 1204.76, 'currency': 'USD', 'merchant_name': 'Flipkart - Automobile - 6199        ', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820055976, 'device_id': '3effc2e9-49d7-4a91-902d-9de532191244', 'location': 'Delhi - IVN', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3151973b-2af5-49a0-b893-5d66b1bb6e80', 'user_id': 'f6a47f09-912e-492f-ab41-b3e2e58aa468', 'amount': 3968.38, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Fashion - Y1AV        ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820056982, 'device_id': '8cdd7b51-8fc1-421b-9f61-2cb5e44ec582', 'location': 'Lucknow - SRO', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '3151973b-2af5-49a0-b893-5d66b1bb6e80', 'user_id': 'f6a47f09-912e-492f-ab41-b3e2e58aa468', 'amount': 3968.38, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Fashion - Y1AV        ', 'merchant_category': ' Fashion', 'transaction_type': 'refund', 'timestamp': 1763820056982, 'device_id': '8cdd7b51-8fc1-421b-9f61-2cb5e44ec582', 'location': 'Lucknow - SRO', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'c67f3c2a-e32b-4a2d-ae53-e5710b3255b4', 'user_id': '765fdcfe-929b-4efa-a0e0-c7cb7e5121e7', 'amount': 4190.83, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - QA1E          ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820057988, 'device_id': 'c30daec4-c72c-4c1f-8a0e-2c097f92022e', 'location': 'Tokyo - VCU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'c67f3c2a-e32b-4a2d-ae53-e5710b3255b4', 'user_id': '765fdcfe-929b-4efa-a0e0-c7cb7e5121e7', 'amount': 4190.83, 'currency': 'USD', 'merchant_name': 'Myntra - Automobile - QA1E          ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820057988, 'device_id': 'c30daec4-c72c-4c1f-8a0e-2c097f92022e', 'location': 'Tokyo - VCU', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7f648860-e7a8-4acd-b281-d4ce5083ddec', 'user_id': '5f41196a-49f1-42e9-a5c6-7cb105c111e1', 'amount': 1570.01, 'currency': 'USD', 'merchant_name': 'Zomato - Automobile - DZY1          ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820058993, 'device_id': '4fade0ed-f980-4399-a623-510fc4d14fb5', 'location': 'London - HJF', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '7f648860-e7a8-4acd-b281-d4ce5083ddec', 'user_id': '5f41196a-49f1-42e9-a5c6-7cb105c111e1', 'amount': 1570.01, 'currency': 'USD', 'merchant_name': 'Zomato - Automobile - DZY1          ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820058993, 'device_id': '4fade0ed-f980-4399-a623-510fc4d14fb5', 'location': 'London - HJF', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2d0068c4-2092-4f6a-8231-f372794e6e65', 'user_id': '5e1a002c-7d4c-4550-b3ad-238073f4de8a', 'amount': 2808.35, 'currency': 'USD', 'merchant_name': 'Reliance - Fashion - RY82           ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820060001, 'device_id': 'e8c47dee-dfe8-49eb-86d6-9e6df3ec2993', 'location': 'Toronto - XGG', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '2d0068c4-2092-4f6a-8231-f372794e6e65', 'user_id': '5e1a002c-7d4c-4550-b3ad-238073f4de8a', 'amount': 2808.35, 'currency': 'USD', 'merchant_name': 'Reliance - Fashion - RY82           ', 'merchant_category': ' Automobile', 'transaction_type': 'withdrawal', 'timestamp': 1763820060001, 'device_id': 'e8c47dee-dfe8-49eb-86d6-9e6df3ec2993', 'location': 'Toronto - XGG', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bf9d1ae9-74dd-4889-87c6-27c1ffd0e105', 'user_id': 'bcbee3e4-d637-437b-8873-4f40c0ea08d4', 'amount': 3424.98, 'currency': 'USD', 'merchant_name': 'Uber - Travel - B0X6                ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820061004, 'device_id': '508a3361-a3a9-461b-a863-f49bc2e69ff0', 'location': 'Jaipur - SQK', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'bf9d1ae9-74dd-4889-87c6-27c1ffd0e105', 'user_id': 'bcbee3e4-d637-437b-8873-4f40c0ea08d4', 'amount': 3424.98, 'currency': 'USD', 'merchant_name': 'Uber - Travel - B0X6                ', 'merchant_category': ' Electronics', 'transaction_type': 'purchase', 'timestamp': 1763820061004, 'device_id': '508a3361-a3a9-461b-a863-f49bc2e69ff0', 'location': 'Jaipur - SQK', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'c4ec2c75-800b-4ff1-9a98-c074bafd2d53', 'user_id': '366b4854-040d-45ca-b789-2acf7a05ab31', 'amount': 3439.91, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Electronics - P43O    ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820062009, 'device_id': '87c2551a-4aa6-4466-b659-3af80846ea53', 'location': 'Tokyo - UIB', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'c4ec2c75-800b-4ff1-9a98-c074bafd2d53', 'user_id': '366b4854-040d-45ca-b789-2acf7a05ab31', 'amount': 3439.91, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Electronics - P43O    ', 'merchant_category': ' Food', 'transaction_type': 'refund', 'timestamp': 1763820062009, 'device_id': '87c2551a-4aa6-4466-b659-3af80846ea53', 'location': 'Tokyo - UIB', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '1baec966-aae8-4302-a7bf-35042529bfbb', 'user_id': 'e431166e-ee99-4996-8a03-3e6f1cd405a0', 'amount': 4997.46, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Online Services - I43T', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820063015, 'device_id': '7423e5d9-d406-4ceb-85f7-7baa1d3f9454', 'location': 'Hyderabad - VWK', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '1baec966-aae8-4302-a7bf-35042529bfbb', 'user_id': 'e431166e-ee99-4996-8a03-3e6f1cd405a0', 'amount': 4997.46, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Online Services - I43T', 'merchant_category': ' Healthcare', 'transaction_type': 'transfer', 'timestamp': 1763820063015, 'device_id': '7423e5d9-d406-4ceb-85f7-7baa1d3f9454', 'location': 'Hyderabad - VWK', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '11ac38d0-398b-4eb0-8ffe-28ccee91cdc8', 'user_id': '37572f15-de1f-4870-a9aa-5a571859a200', 'amount': 777.14, 'currency': 'USD', 'merchant_name': 'Uber - Online Services - OP3B       ', 'merchant_category': ' Healthcare', 'transaction_type': 'purchase', 'timestamp': 1763820064023, 'device_id': '5a71a5df-2432-4a9c-9c5f-a6badfca6d65', 'location': 'Lagos - XKG', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '11ac38d0-398b-4eb0-8ffe-28ccee91cdc8', 'user_id': '37572f15-de1f-4870-a9aa-5a571859a200', 'amount': 777.14, 'currency': 'USD', 'merchant_name': 'Uber - Online Services - OP3B       ', 'merchant_category': ' Healthcare', 'transaction_type': 'purchase', 'timestamp': 1763820064023, 'device_id': '5a71a5df-2432-4a9c-9c5f-a6badfca6d65', 'location': 'Lagos - XKG', 'status': 'completed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'fa802a0f-a631-4a00-afbe-f46cfdab39e6', 'user_id': '66ccdd18-5d17-4e33-8d60-1cad4a9bdfe7', 'amount': 906.04, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Grocery - D8RW        ', 'merchant_category': ' Fashion', 'transaction_type': 'purchase', 'timestamp': 1763820065028, 'device_id': '5f646fd9-cafd-4614-9bcd-69261195edd7', 'location': 'New York - XOG', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'fa802a0f-a631-4a00-afbe-f46cfdab39e6', 'user_id': '66ccdd18-5d17-4e33-8d60-1cad4a9bdfe7', 'amount': 906.04, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Grocery - D8RW        ', 'merchant_category': ' Fashion', 'transaction_type': 'purchase', 'timestamp': 1763820065028, 'device_id': '5f646fd9-cafd-4614-9bcd-69261195edd7', 'location': 'New York - XOG', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'eae0fbaf-450f-41d9-8dc5-5d3e49870b72', 'user_id': '3de20853-0ac3-4803-8fa5-3ea1217f2f52', 'amount': 749.95, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Automobile - 62T1     ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820066031, 'device_id': '3cb82e0b-da13-4194-bd5f-69142e93b6c8', 'location': 'Lagos - TYL', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': 'eae0fbaf-450f-41d9-8dc5-5d3e49870b72', 'user_id': '3de20853-0ac3-4803-8fa5-3ea1217f2f52', 'amount': 749.95, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Automobile - 62T1     ', 'merchant_category': ' Electronics', 'transaction_type': 'transfer', 'timestamp': 1763820066031, 'device_id': '3cb82e0b-da13-4194-bd5f-69142e93b6c8', 'location': 'Lagos - TYL', 'status': 'failed'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '17fcd12c-2e87-4fb4-a318-579dce131fac', 'user_id': 'bdc868c5-b322-40a8-bbba-b420036f5d06', 'amount': 2940.36, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Grocery - HX5P        ', 'merchant_category': ' Food', 'transaction_type': 'transfer', 'timestamp': 1763820067035, 'device_id': '0d300cb7-7541-4605-9842-26a52d953b70', 'location': 'Tokyo - ZJV', 'status': 'pending'}
# Encoding event to Avro using fastavro
# Sent: {'transaction_id': '17fcd12c-2e87-4fb4-a318-579dce131fac', 'user_id': 'bdc868c5-b322-40a8-bbba-b420036f5d06', 'amount': 2940.36, 'currency': 'USD', 'merchant_name': 'LocalBazaar - Grocery - HX5P        ', 'merchant_category': ' Food', 'transaction_type': 'transfer', 'timestamp': 1763820067035, 'device_id': '0d300cb7-7541-4605-9842-26a52d953b70', 'location': 'Tokyo - ZJV', 'status': 'pending'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       5 sent_event = send_single_message('transactions', producer=p)
#       6 print('Sent:', sent_event)
# ----> 7 sleep(1)
#
# KeyboardInterrupt:

# %%
p.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 p.close()
#
# AttributeError: 'cimpl.Producer' object has no attribute 'close'
